# %%
from PIL import Image

# %%
mac = Image.open('compressjpgcompressjpgVishal_Karur_Photo.jpeg')

# %%
type(mac)
# Out:
# PIL.JpegImagePlugin.JpegImageFile

# %%
mac
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1014x1280 at 0x1FF55E0B370>

# %%
mac.size
# Out:
# (1014, 1280)

# %%
 mac.format_description
# Out:
# 'JPEG (ISO 10918)'

# %%
mac.filename
# Out:
# 'compressjpgcompressjpgVishal_Karur_Photo.jpeg'

# %% [markdown]
# Cropping Images

# %%
x=0
y=0

# %%
w = 1014/3
h = 1280 / 10

# %%
mac.crop((x,y,w,h))
# Out:
# <PIL.Image.Image image mode=RGB size=338x128 at 0x1FF55E66DF0>

# %%
halfway = 1014 / 2

# %%
w = halfway -200
h = halfway +200

# %%
computer = mac.crop((x,y,w,h))

# %%
mac.paste(im=computer,box = (0,0))

# %%
mac
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1014x1280 at 0x1FF55E0B370>

# %%
mac.resize((100,100))
# Out:
# <PIL.Image.Image image mode=RGB size=100x100 at 0x1FF55B908E0>

# %%
mac.rotate(270)
# Out:
# <PIL.Image.Image image mode=RGB size=1014x1280 at 0x1FF55E664C0>

# %% [markdown]
# RGBA values
# alpha = 0 is fully transparent
